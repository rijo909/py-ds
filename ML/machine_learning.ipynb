# %% [markdown]
# Machine Learning (ML) in Brief
# Machine Learning (ML) is a subset of Artificial Intelligence (AI) that focuses on building systems
# that can learn from data and make predictions or decisions without being explicitly programmed.
# Instead of writing rules, ML algorithms identify patterns in data and use them to make predictions
# or decisions.

# %% [markdown]
# ML: Teaching computers to learn from data and make predictions.
# Model: A mathematical representation of patterns in data.
# Types of Models: Linear, tree-based, neural networks, clustering, etc.

# %% [markdown]
# 1. Supervised Learning
# Supervised learning involves training a model on labeled data (input-output pairs).
# The goal is to learn a mapping from inputs to outputs.
#
# Types of Supervised Learning:
# Classification: Predicts a categorical label.
#
# Regression: Predicts a continuous value.

# %% [markdown]
# 2. Unsupervised Learning
# Unsupervised learning involves training a model on unlabeled data.
# The goal is to find patterns or groupings in the data.
#
# Types of Unsupervised Learning:
# Clustering: Groups similar data points together.
#
# Dimensionality Reduction: Reduces the number of features while preserving important information.

# %% [markdown]
# 3. Reinforcement Learning
# Reinforcement learning involves training an agent to make decisions by interacting
# with an environment and receiving feedback (rewards or penalties).
#
# Example: Reinforcement Learning (using Gym)

# %% [markdown]
# 4. Deep Learning
# Deep learning uses neural networks with multiple layers to model complex patterns in data.
# It is used for tasks like image recognition, natural language processing, etc.
#
# Example: Deep Learning (using TensorFlow/Keras)

# %% [markdown]
# 5. Ensemble Learning
# Ensemble learning combines multiple models to improve performance.
# Common techniques include bagging, boosting, and stacking.
#
# Example: Boosting (XGBoost)
